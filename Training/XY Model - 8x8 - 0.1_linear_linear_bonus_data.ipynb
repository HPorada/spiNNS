# %%
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, LeakyReLU

# %%
dataset = np.load("dataset_8_01.npy")
short_dataset = np.load("short_dataset_8_01.npy")
combined_dataset = np.concatenate((dataset, short_dataset), axis=0)
print("Combined dataset shape:", combined_dataset.shape)
# Out:
# Combined dataset shape: (199780, 2, 128)

# %%
input_shape = (128,)
epochs = 100
batch_size = 1000

# %%
inputs = np.array(combined_dataset[:, 0])
outputs = np.array(combined_dataset[:, 1])

# %%
inputs_train, inputs_test, outputs_train, outputs_test = train_test_split(inputs, outputs, test_size=0.15, random_state=73)

# %%
inputs_train, inputs_val, outputs_train, outputs_val = train_test_split(inputs_train, outputs_train, test_size=0.1, random_state=73)

# %%
inputs_train = np.array(inputs_train)
outputs_train = np.array(outputs_train)
inputs_test = np.array(inputs_test)
outputs_test = np.array(outputs_test)
inputs_val = np.array(inputs_val)
outputs_val = np.array(outputs_val)

# %%
print(len(inputs_train))
print(len(inputs_test))
print(len(inputs_val))
# Out:
# 152831
# 29967
# 16982

# %%
print(inputs_train[0])
# Out:
# [-0.82598887 -0.93942603 -0.94448998 -0.91705198 -0.8969339  -0.94256391
#  -0.91702164 -0.69336565 -0.93533726 -0.8944864  -0.93078444 -0.96565758
#  -0.91134191 -0.98747428 -0.95894074 -0.77594786 -0.93276164 -0.97480335
#  -0.95106501 -0.90907206 -0.91858446 -0.9346192  -0.93825566 -0.92367781
#  -0.86677554 -0.92928692 -0.96217082 -0.92136341 -0.91310185 -0.8037469
#  -0.90611545 -0.90837794 -0.94359606 -0.94370285 -0.92364745 -0.84679408
#  -0.94290474 -0.99770813 -0.7983572  -0.91057089 -0.91888823 -0.96923143
#  -0.96323181 -0.99116437 -0.91971945 -0.91744649 -0.93489467 -0.98121624
#  -0.77127094 -0.91739369 -0.94612634 -0.92139394 -0.97076403 -0.96184236
#  -0.86517116 -0.91993101 -0.81880909 -0.90293416 -0.8824458  -0.95338406
#  -0.87545975 -0.93666739 -0.99578085 -0.92282905  0.56368643  0.3427517
#   0.32854022  0.39876768  0.44216466  0.33402586  0.39883745  0.72058592
#   0.35375729  0.44709517  0.36556849  0.25981807  0.41165025  0.15778007
#   0.28360651  0.63079704  0.36049371  0.22306595  0.30899087  0.41663893
#   0.39522474  0.35565004  0.34594265  0.38317008  0.49869846  0.36935866
#   0.2724469   0.38870229  0.40773155  0.59497136  0.42303047  0.41815012
#   0.33109889  0.3307944   0.38324324  0.53192084  0.33306254  0.06766456
#   0.60218418  0.41335294  0.39451797  0.24615126  0.26867169  0.13263935
#   0.39257628  0.3978592   0.35492527  0.19291108  0.63650698  0.39798094
#   0.32379771  0.38862991  0.24003581  0.27360423  0.50147668  0.39208027
#   0.57406592  0.42977889  0.47041408  0.30175957  0.48329104  0.35022022
#  -0.09176332  0.38520973]

# %%
def autoencoder_dense_1(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))
    # Encoder
    model.add(Dense(64, activation='linear'))
    # Decoder
    model.add(Dense(128, activation='linear'))
    return model

def autoencoder_dense_2(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))
    # Encoder
    model.add(Dense(64, activation='linear'))
    model.add(Dense(32, activation='linear'))
    # Decoder
    model.add(Dense(64, activation='linear'))
    model.add(Dense(128, activation='linear'))
    return model

def autoencoder_dense_3(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))
    # Encoder
    model.add(Dense(64, activation='linear'))
    model.add(Dense(32, activation='linear'))
    model.add(Dense(16, activation='linear'))
    # Decoder
    model.add(Dense(32, activation='linear'))
    model.add(Dense(64, activation='linear'))
    model.add(Dense(128, activation='linear'))
    return model

# %%
optimizer = Adam(learning_rate=0.001)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
dense_1 = autoencoder_dense_1(input_shape)
dense_1.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['accuracy'])

# %%
history_d1 = dense_1.fit(
                inputs_train, 
                outputs_train, 
                epochs=epochs, 
                batch_size=batch_size, 
                shuffle=False,
                callbacks=[lr_scheduler],
                validation_data=(inputs_test, outputs_test))
# Out:
# Epoch 1/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0190 - loss: 0.2478 - val_accuracy: 0.0405 - val_loss: 0.0413 - learning_rate: 0.0010
# Epoch 2/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0454 - loss: 0.0365 - val_accuracy: 0.0622 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 3/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0670 - loss: 0.0252 - val_accuracy: 0.0837 - val_loss: 0.0212 - learning_rate: 0.0010
# Epoch 4/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0879 - loss: 0.0202 - val_accuracy: 0.1037 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 5/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1089 - loss: 0.0173 - val_accuracy: 0.1230 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 6/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1271 - loss: 0.0153 - val_accuracy: 0.1387 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 7/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1425 - loss: 0.0138 - val_accuracy: 0.1532 - val_loss: 0.0130 - learning_rate: 0.0010
# Epoch 8/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1555 - loss: 0.0128 - val_accuracy: 0.1645 - val_loss: 0.0122 - learning_rate: 0.0010
# Epoch 9/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1646 - loss: 0.0120 - val_accuracy: 0.1724 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 10/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1724 - loss: 0.0113 - val_accuracy: 0.1789 - val_loss: 0.0110 - learning_rate: 0.0010
# Epoch 11/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1791 - loss: 0.0108 - val_accuracy: 0.1844 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 12/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1840 - loss: 0.0104 - val_accuracy: 0.1876 - val_loss: 0.0102 - learning_rate: 0.0010
# Epoch 13/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1886 - loss: 0.0101 - val_accuracy: 0.1909 - val_loss: 0.0099 - learning_rate: 0.0010
# Epoch 14/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1928 - loss: 0.0098 - val_accuracy: 0.1936 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 15/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1973 - loss: 0.0096 - val_accuracy: 0.1959 - val_loss: 0.0094 - learning_rate: 0.0010
# Epoch 16/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1997 - loss: 0.0094 - val_accuracy: 0.1981 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 17/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2018 - loss: 0.0092 - val_accuracy: 0.2012 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 18/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2040 - loss: 0.0091 - val_accuracy: 0.2024 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 19/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2060 - loss: 0.0090 - val_accuracy: 0.2039 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 20/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2068 - loss: 0.0089 - val_accuracy: 0.2046 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 21/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2075 - loss: 0.0088 - val_accuracy: 0.2055 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 22/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2084 - loss: 0.0087 - val_accuracy: 0.2066 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 23/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2088 - loss: 0.0086 - val_accuracy: 0.2084 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 24/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2096 - loss: 0.0086 - val_accuracy: 0.2088 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 25/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2112 - loss: 0.0085 - val_accuracy: 0.2099 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 26/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2114 - loss: 0.0085 - val_accuracy: 0.2105 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 27/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2117 - loss: 0.0084 - val_accuracy: 0.2115 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 28/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2123 - loss: 0.0084 - val_accuracy: 0.2117 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 29/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2126 - loss: 0.0083 - val_accuracy: 0.2115 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 30/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2130 - loss: 0.0083 - val_accuracy: 0.2127 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 31/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2134 - loss: 0.0083 - val_accuracy: 0.2130 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 32/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2134 - loss: 0.0083 - val_accuracy: 0.2144 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 33/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2142 - loss: 0.0082 - val_accuracy: 0.2146 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 34/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2144 - loss: 0.0082 - val_accuracy: 0.2155 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 35/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2142 - loss: 0.0082 - val_accuracy: 0.2155 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 36/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2145 - loss: 0.0082 - val_accuracy: 0.2156 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 37/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2143 - loss: 0.0082 - val_accuracy: 0.2164 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 38/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2157 - loss: 0.0081 - val_accuracy: 0.2178 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 39/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2157 - loss: 0.0081 - val_accuracy: 0.2176 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 40/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2159 - loss: 0.0081 - val_accuracy: 0.2171 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 41/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2161 - loss: 0.0081 - val_accuracy: 0.2169 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 42/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2160 - loss: 0.0081 - val_accuracy: 0.2164 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 43/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2161 - loss: 0.0081 - val_accuracy: 0.2167 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 44/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2162 - loss: 0.0081 - val_accuracy: 0.2171 - val_loss: 0.0080 - learning_rate: 2.5000e-04
# Epoch 45/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2166 - loss: 0.0081 - val_accuracy: 0.2172 - val_loss: 0.0080 - learning_rate: 2.5000e-04
# Epoch 46/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2166 - loss: 0.0081 - val_accuracy: 0.2176 - val_loss: 0.0080 - learning_rate: 2.5000e-04
# Epoch 47/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2165 - loss: 0.0081 - val_accuracy: 0.2176 - val_loss: 0.0080 - learning_rate: 2.5000e-04
# Epoch 48/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2165 - loss: 0.0081 - val_accuracy: 0.2176 - val_loss: 0.0080 - learning_rate: 2.5000e-04
# Epoch 49/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2169 - loss: 0.0080 - val_accuracy: 0.2184 - val_loss: 0.0080 - learning_rate: 1.2500e-04
# Epoch 50/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2165 - loss: 0.0080 - val_accuracy: 0.2181 - val_loss: 0.0080 - learning_rate: 1.2500e-04
# Epoch 51/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2164 - loss: 0.0080 - val_accuracy: 0.2180 - val_loss: 0.0080 - learning_rate: 1.2500e-04
# Epoch 52/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2165 - loss: 0.0080 - val_accuracy: 0.2183 - val_loss: 0.0080 - learning_rate: 1.2500e-04
# Epoch 53/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2165 - loss: 0.0080 - val_accuracy: 0.2185 - val_loss: 0.0080 - learning_rate: 1.2500e-04
# Epoch 54/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2166 - loss: 0.0080 - val_accuracy: 0.2176 - val_loss: 0.0080 - learning_rate: 6.2500e-05
# Epoch 55/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2166 - loss: 0.0080 - val_accuracy: 0.2174 - val_loss: 0.0080 - learning_rate: 6.2500e-05
# Epoch 56/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2166 - loss: 0.0080 - val_accuracy: 0.2175 - val_loss: 0.0080 - learning_rate: 6.2500e-05
# Epoch 57/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2167 - loss: 0.0080 - val_accuracy: 0.2175 - val_loss: 0.0080 - learning_rate: 6.2500e-05
# Epoch 58/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2167 - loss: 0.0080 - val_accuracy: 0.2173 - val_loss: 0.0080 - learning_rate: 6.2500e-05
# Epoch 59/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2172 - loss: 0.0080 - val_accuracy: 0.2180 - val_loss: 0.0080 - learning_rate: 3.1250e-05
# Epoch 60/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2173 - loss: 0.0080 - val_accuracy: 0.2178 - val_loss: 0.0080 - learning_rate: 3.1250e-05
# Epoch 61/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2174 - loss: 0.0080 - val_accuracy: 0.2178 - val_loss: 0.0080 - learning_rate: 3.1250e-05
# Epoch 62/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2175 - loss: 0.0080 - val_accuracy: 0.2180 - val_loss: 0.0080 - learning_rate: 3.1250e-05
# Epoch 63/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2174 - loss: 0.0080 - val_accuracy: 0.2179 - val_loss: 0.0080 - learning_rate: 3.1250e-05
# Epoch 64/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2173 - loss: 0.0080 - val_accuracy: 0.2178 - val_loss: 0.0080 - learning_rate: 1.5625e-05
# Epoch 65/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2172 - loss: 0.0080 - val_accuracy: 0.2178 - val_loss: 0.0080 - learning_rate: 1.5625e-05
# Epoch 66/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2173 - loss: 0.0080 - val_accuracy: 0.2178 - val_loss: 0.0080 - learning_rate: 1.5625e-05
# Epoch 67/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2173 - loss: 0.0080 - val_accuracy: 0.2179 - val_loss: 0.0080 - learning_rate: 1.5625e-05
# Epoch 68/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2173 - loss: 0.0080 - val_accuracy: 0.2181 - val_loss: 0.0080 - learning_rate: 1.5625e-05
# Epoch 69/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2172 - loss: 0.0080 - val_accuracy: 0.2177 - val_loss: 0.0080 - learning_rate: 7.8125e-06
# Epoch 70/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2171 - loss: 0.0080 - val_accuracy: 0.2176 - val_loss: 0.0080 - learning_rate: 7.8125e-06
# Epoch 71/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.
- val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 24/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1347 - loss: 0.0126 - val_accuracy: 0.1377 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 25/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1342 - loss: 0.0126 - val_accuracy: 0.1367 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 26/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1336 - loss: 0.0126 - val_accuracy: 0.1367 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 27/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1337 - loss: 0.0125 - val_accuracy: 0.1370 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 28/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1338 - loss: 0.0125 - val_accuracy: 0.1369 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 29/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1337 - loss: 0.0125 - val_accuracy: 0.1388 - val_loss: 0.0125 - learning_rate: 5.0000e-04
# Epoch 30/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1334 - loss: 0.0125 - val_accuracy: 0.1391 - val_loss: 0.0125 - learning_rate: 5.0000e-04
# Epoch 31/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1332 - loss: 0.0125 - val_accuracy: 0.1389 - val_loss: 0.0125 - learning_rate: 5.0000e-04
# Epoch 32/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1333 - loss: 0.0125 - val_accuracy: 0.1385 - val_loss: 0.0125 - learning_rate: 5.0000e-04
# Epoch 33/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1334 - loss: 0.0124 - val_accuracy: 0.1385 - val_loss: 0.0125 - learning_rate: 5.0000e-04
# Epoch 34/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1340 - loss: 0.0124 - val_accuracy: 0.1381 - val_loss: 0.0125 - learning_rate: 5.0000e-04
# Epoch 35/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1345 - loss: 0.0124 - val_accuracy: 0.1378 - val_loss: 0.0124 - learning_rate: 2.5000e-04
# Epoch 36/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1343 - loss: 0.0124 - val_accuracy: 0.1375 - val_loss: 0.0124 - learning_rate: 2.5000e-04
# Epoch 37/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1337 - loss: 0.0124 - val_accuracy: 0.1378 - val_loss: 0.0124 - learning_rate: 2.5000e-04
# Epoch 38/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1337 - loss: 0.0124 - val_accuracy: 0.1381 - val_loss: 0.0124 - learning_rate: 2.5000e-04
# Epoch 39/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1341 - loss: 0.0124 - val_accuracy: 0.1381 - val_loss: 0.0124 - learning_rate: 2.5000e-04
# Epoch 40/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1343 - loss: 0.0124 - val_accuracy: 0.1376 - val_loss: 0.0124 - learning_rate: 1.2500e-04
# Epoch 41/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1338 - loss: 0.0124 - val_accuracy: 0.1377 - val_loss: 0.0124 - learning_rate: 1.2500e-04
# Epoch 42/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1340 - loss: 0.0124 - val_accuracy: 0.1376 - val_loss: 0.0124 - learning_rate: 1.2500e-04
# Epoch 43/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1339 - loss: 0.0124 - val_accuracy: 0.1380 - val_loss: 0.0124 - learning_rate: 1.2500e-04
# Epoch 44/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1338 - loss: 0.0124 - val_accuracy: 0.1380 - val_loss: 0.0124 - learning_rate: 1.2500e-04
# Epoch 45/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1337 - loss: 0.0124 - val_accuracy: 0.1386 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 46/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1342 - loss: 0.0124 - val_accuracy: 0.1386 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 47/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1341 - loss: 0.0124 - val_accuracy: 0.1386 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 48/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1341 - loss: 0.0124 - val_accuracy: 0.1389 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 49/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1340 - loss: 0.0124 - val_accuracy: 0.1388 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 50/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1340 - loss: 0.0124 - val_accuracy: 0.1388 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 51/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1338 - loss: 0.0124 - val_accuracy: 0.1386 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 52/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1339 - loss: 0.0124 - val_accuracy: 0.1387 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 53/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1339 - loss: 0.0124 - val_accuracy: 0.1387 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 54/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1339 - loss: 0.0124 - val_accuracy: 0.1387 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 55/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1341 - loss: 0.0124 - val_accuracy: 0.1390 - val_loss: 0.0124 - learning_rate: 1.5625e-05
# Epoch 56/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1337 - loss: 0.0124 - val_accuracy: 0.1390 - val_loss: 0.0124 - learning_rate: 1.5625e-05
# Epoch 57/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1337 - loss: 0.0124 - val_accuracy: 0.1389 - val_loss: 0.0124 - learning_rate: 1.5625e-05
# Epoch 58/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1338 - loss: 0.0124 - val_accuracy: 0.1388 - val_loss: 0.0124 - learning_rate: 1.5625e-05
# Epoch 59/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1337 - loss: 0.0124 - val_accuracy: 0.1388 - val_loss: 0.0124 - learning_rate: 1.5625e-05
# Epoch 60/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1339 - loss: 0.0124 - val_accuracy: 0.
# Epoch 49/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0053 - loss: 0.4919 - val_accuracy: 0.0046 - val_loss: 0.5547 - learning_rate: 5.0000e-04
# Epoch 50/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0052 - loss: 0.4911 - val_accuracy: 0.0048 - val_loss: 0.5531 - learning_rate: 5.0000e-04
# Epoch 51/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0052 - loss: 0.4896 - val_accuracy: 0.0046 - val_loss: 0.5531 - learning_rate: 5.0000e-04
# Epoch 52/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.0050 - loss: 0.4924 - val_accuracy: 0.0040 - val_loss: 0.5553 - learning_rate: 5.0000e-04
# Epoch 53/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0050 - loss: 0.4930 - val_accuracy: 0.0044 - val_loss: 0.5538 - learning_rate: 5.0000e-04
# Epoch 54/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.0049 - loss: 0.4881 - val_accuracy: 0.0044 - val_loss: 0.5510 - learning_rate: 5.0000e-04
# Epoch 55/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0050 - loss: 0.4875 - val_accuracy: 0.0047 - val_loss: 0.5572 - learning_rate: 5.0000e-04
# Epoch 56/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.0049 - loss: 0.4948 - val_accuracy: 0.0039 - val_loss: 0.5513 - learning_rate: 5.0000e-04
# Epoch 57/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.0049 - loss: 0.4848 - val_accuracy: 0.0040 - val_loss: 0.5548 - learning_rate: 5.0000e-04
# Epoch 58/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.0048 - loss: 0.4946 - val_accuracy: 0.0054 - val_loss: 0.5607 - learning_rate: 5.0000e-04
# Epoch 59/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0055 - loss: 0.4968 - val_accuracy: 0.0045 - val_loss: 0.5510 - learning_rate: 5.0000e-04
# Epoch 60/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0051 - loss: 0.4821 - val_accuracy: 0.0045 - val_loss: 0.5431 - learning_rate: 2.5000e-04
# Epoch 61/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.0051 - loss: 0.4743 - val_accuracy: 0.0045 - val_loss: 0.5418 - learning_rate: 2.5000e-04
# Epoch 62/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.0051 - loss: 0.4702 - val_accuracy: 0.0046 - val_loss: 0.5387 - learning_rate: 2.5000e-04
# Epoch 63/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.0050 - loss: 0.4687 - val_accuracy: 0.0045 - val_loss: 0.5395 - learning_rate: 2.5000e-04
# Epoch 64/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.0052 - loss: 0.4667 - val_accuracy: 0.0046 - val_loss: 0.5384 - learning_rate: 2.5000e-04
# Epoch 65/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0052 - loss: 0.4657 - val_accuracy: 0.0046 - val_loss: 0.5390 - learning_rate: 2.5000e-04
# Epoch 66/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0053 - loss: 0.4659 - val_accuracy: 0.0046 - val_loss: 0.5357 - learning_rate: 2.5000e-04
# Epoch 67/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4644 - val_accuracy: 0.0047 - val_loss: 0.5378 - learning_rate: 2.5000e-04
# Epoch 68/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0051 - loss: 0.4640 - val_accuracy: 0.0048 - val_loss: 0.5378 - learning_rate: 2.5000e-04
# Epoch 69/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0052 - loss: 0.4631 - val_accuracy: 0.0049 - val_loss: 0.5376 - learning_rate: 2.5000e-04
# Epoch 70/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4621 - val_accuracy: 0.0047 - val_loss: 0.5366 - learning_rate: 2.5000e-04
# Epoch 71/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0050 - loss: 0.4628 - val_accuracy: 0.0047 - val_loss: 0.5356 - learning_rate: 2.5000e-04
# Epoch 72/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.0051 - loss: 0.4589 - val_accuracy: 0.0044 - val_loss: 0.5308 - learning_rate: 1.2500e-04
# Epoch 73/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.0050 - loss: 0.4556 - val_accuracy: 0.0047 - val_loss: 0.5300 - learning_rate: 1.2500e-04
# Epoch 74/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.0051 - loss: 0.4545 - val_accuracy: 0.0046 - val_loss: 0.5300 - learning_rate: 1.2500e-04
# Epoch 75/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0051 - loss: 0.4538 - val_accuracy: 0.0046 - val_loss: 0.5302 - learning_rate: 1.2500e-04
# Epoch 76/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.0050 - loss: 0.4534 - val_accuracy: 0.0046 - val_loss: 0.5296 - learning_rate: 1.2500e-04
# Epoch 77/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0052 - loss: 0.4528 - val_accuracy: 0.0047 - val_loss: 0.5311 - learning_rate: 1.2500e-04
# Epoch 78/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.0051 - loss: 0.4529 - val_accuracy: 0.0047 - val_loss: 0.5303 - learning_rate: 1.2500e-04
# Epoch 79/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4525 - val_accuracy: 0.0047 - val_loss: 0.5291 - learning_rate: 1.2500e-04
# Epoch 80/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0051 - loss: 0.4527 - val_accuracy: 0.0047 - val_loss: 0.5298 - learning_rate: 1.2500e-04
# Epoch 81/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4521 - val_accuracy: 0.0047 - val_loss: 0.5283 - learning_rate: 1.2500e-04
# Epoch 82/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0052 - loss: 0.4512 - val_accuracy: 0.0047 - val_loss: 0.5281 - learning_rate: 1.2500e-04
# Epoch 83/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0052 - loss: 0.4514 - val_accuracy: 0.0048 - val_loss: 0.5287 - learning_rate: 1.2500e-04
# Epoch 84/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0051 - loss: 0.4509 - val_accuracy: 0.0048 - val_loss: 0.5281 - learning_rate: 1.2500e-04
# Epoch 85/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4506 - val_accuracy: 0.0047 - val_loss: 0.5272 - learning_rate: 1.2500e-04
# Epoch 86/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0051 - loss: 0.4496 - val_accuracy: 0.0048 - val_loss: 0.5281 - learning_rate: 1.2500e-04
# Epoch 87/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.0052 - loss: 0.4495 - val_accuracy: 0.0047 - val_loss: 0.5285 - learning_rate: 1.2500e-04
# Epoch 88/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4503 - val_accuracy: 0.0047 - val_loss: 0.5269 - learning_rate: 1.2500e-04
# Epoch 89/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4488 - val_accuracy: 0.0047 - val_loss: 0.5273 - learning_rate: 1.2500e-04
# Epoch 90/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0050 - loss: 0.4486 - val_accuracy: 0.0045 - val_loss: 0.5269 - learning_rate: 1.2500e-04
# Epoch 91/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.0051 - loss: 0.4488 - val_accuracy: 0.0045 - val_loss: 0.5270 - learning_rate: 1.2500e-04
# Epoch 92/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0052 - loss: 0.4481 - val_accuracy: 0.0045 - val_loss: 0.5267 - learning_rate: 1.2500e-04
# Epoch 93/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.0051 - loss: 0.4484 - val_accuracy: 0.0045 - val_loss: 0.5259 - learning_rate: 1.2500e-04
# Epoch 94/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0051 - loss: 0.4482 - val_accuracy: 0.0047 - val_loss: 0.5264 - learning_rate: 1.2500e-04
# Epoch 95/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0051 - loss: 0.4477 - val_accuracy: 0.0046 - val_loss: 0.5270 - learning_rate: 1.2500e-04
# Epoch 96/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0051 - loss: 0.4477 - val_accuracy: 0.0046 - val_loss: 0.5254 - learning_rate: 1.2500e-04
# Epoch 97/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0051 - loss: 0.4473 - val_accuracy: 0.0047 - val_loss: 0.5262 - learning_rate: 1.2500e-04
# Epoch 98/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 0.0052 - loss: 0.4474 - val_accuracy: 0.0046 - val_loss: 0.5257 - learning_rate: 1.2500e-04
# Epoch 99/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.0051 - loss: 0.4477 - val_accuracy: 0.0049 - val_loss: 0.5279 - learning_rate: 1.2500e-04
# Epoch 100/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.0051 - loss: 0.4507 - val_accuracy: 0.0047 - val_loss: 0.5256 - learning_rate: 1.2500e-04

# %%
plt.plot(history_d2_ed.history['loss'], label='Training Loss')
plt.plot(history_d2_ed.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

plt.plot(history_d2_ed.history['accuracy'], label='Training accuracy')
plt.plot(history_d2_ed.history['val_accuracy'], label='Test accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
optimizer = Adam(learning_rate=0.001)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
dense_3_ed = autoencoder_dense_3(input_shape)
dense_3_ed.compile(optimizer=optimizer, loss=energy_difference, metrics=['accuracy'])

# %%
history_d3_ed = dense_3_ed.fit(
                inputs_train, 
                outputs_train, 
                epochs=epochs, 
                batch_size=batch_size, 
                shuffle=False,
                callbacks=[lr_scheduler],
                validation_data=(inputs_test, outputs_test))
# Out:
# Epoch 1/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 14s 63ms/step
# Epoch 85/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.0013 - loss: 0.5840 - val_accuracy: 0.0010 - val_loss: 0.6466 - learning_rate: 0.0010
# Epoch 86/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.0011 - loss: 0.5842 - val_accuracy: 0.0016 - val_loss: 0.6469 - learning_rate: 0.0010
# Epoch 87/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.0013 - loss: 0.5892 - val_accuracy: 0.0020 - val_loss: 0.6397 - learning_rate: 0.0010
# Epoch 88/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.0016 - loss: 0.5682 - val_accuracy: 0.0019 - val_loss: 0.6276 - learning_rate: 5.0000e-04
# Epoch 89/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.0016 - loss: 0.5631 - val_accuracy: 0.0020 - val_loss: 0.6214 - learning_rate: 5.0000e-04
# Epoch 90/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.0018 - loss: 0.5574 - val_accuracy: 0.0020 - val_loss: 0.6228 - learning_rate: 5.0000e-04
# Epoch 91/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0017 - loss: 0.5578 - val_accuracy: 0.0019 - val_loss: 0.6214 - learning_rate: 5.0000e-04
# Epoch 92/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.0017 - loss: 0.5578 - val_accuracy: 0.0017 - val_loss: 0.6244 - learning_rate: 5.0000e-04
# Epoch 93/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.0017 - loss: 0.5577 - val_accuracy: 0.0017 - val_loss: 0.6177 - learning_rate: 5.0000e-04
# Epoch 94/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.0016 - loss: 0.5525 - val_accuracy: 0.0019 - val_loss: 0.6207 - learning_rate: 5.0000e-04
# Epoch 95/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.0017 - loss: 0.5525 - val_accuracy: 0.0016 - val_loss: 0.6205 - learning_rate: 5.0000e-04
# Epoch 96/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0015 - loss: 0.5538 - val_accuracy: 0.0018 - val_loss: 0.6209 - learning_rate: 5.0000e-04
# Epoch 97/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0016 - loss: 0.5531 - val_accuracy: 0.0018 - val_loss: 0.6207 - learning_rate: 5.0000e-04
# Epoch 98/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.0015 - loss: 0.5539 - val_accuracy: 0.0016 - val_loss: 0.6525 - learning_rate: 5.0000e-04
# Epoch 99/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0016 - loss: 0.5628 - val_accuracy: 0.0018 - val_loss: 0.6109 - learning_rate: 2.5000e-04
# Epoch 100/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.0017 - loss: 0.5438 - val_accuracy: 0.0020 - val_loss: 0.6176 - learning_rate: 2.5000e-04

# %%
plt.plot(history_d3_ed.history['loss'], label='Training Loss')
plt.plot(history_d3_ed.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

plt.plot(history_d3_ed.history['accuracy'], label='Training accuracy')
plt.plot(history_d3_ed.history['val_accuracy'], label='Test accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
histories = [history_d1, history_d2, history_d3]
histories_ed = [history_d1_ed, history_d2_ed, history_d3_ed]
colors = ["blue", "orange", "green", "red", "purple", "brown", "pink", "gray", "lime", "cyan"]
names = ["dense_1", "dense_2", "dense_3", "dense_1_custom_loss", "dense_2_custom_loss", "dense_3_custom_loss"]

# %%
import matplotlib.pyplot as plt

def plot_training_histories(histories, colors, names, skip=0):
    """Plots training and validation loss curves for multiple models.

    Args:
        histories (list): List of Keras History objects.
        colors (list): List of colors for each model's line.
        names (list): List of names for each model.
    """

    plt.figure(figsize=(12, 4))

    for history, color, name in zip(histories, colors, names):
        # Extract training and validation loss from history
        train_loss = history.history['loss'][skip:]
        val_loss = history.history['val_loss'][skip:]
        epochs = range(1, len(train_loss) + 1)

        # Plot training loss (solid line)
        plt.plot(epochs, train_loss, color=color, label=f'{name} (train)', linestyle='-')

        # Plot validation loss (dashed line)
        plt.plot(epochs, val_loss, color=color, label=f'{name} (val)', linestyle='--')

    # Add labels, title, and legend
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Show the plot
    plt.grid(True)
    plt.show()

# %%
# ... (Your code to train multiple models, storing histories in the 'histories' list)
plot_training_histories(histories, colors, names, skip=1)
plot_training_histories(histories_ed, colors, names, skip=1)

# %%
models = [dense_1, dense_2, dense_3, dense_1_ed, dense_2_ed, dense_3_ed]
model_histories = [history_d1, history_d2, history_d3, history_d1_ed, history_d2_ed, history_d3_ed]
names_models = ["dense_1_8_01_linear_linear", "dense_2_8_01_linear_linear", "dense_3_8_01_linear_linear", "dense_1_custom_loss_8_01_linear_linear", "dense_2_custom_loss_8_01_linear_linear", "dense_3_custom_loss_8_01_linear_linear"]

# %%
import pickle

for i, model in enumerate(models):
    model.save(f"C:/Users/hmpor/Jupyter Notebooks/Thesis/Model training/Models/LL_bonus/{names_models[i]}.h5")
    model.save(f"C:/Users/hmpor/Jupyter Notebooks/Thesis/Model training/Models/LL_bonus/{names_models[i]}.keras")

    
    with open(f"C:/Users/hmpor/Jupyter Notebooks/Thesis/Model training/Models/LL_bonus/{names_models[i]}.pkl", "wb") as pickle_file:
        pickle.dump(model_histories[i].history, pickle_file)
    # Save the entire model to a HDF5 file
#     autoencoder_energy_2.save('C:/Users/hmpor/Jupyter Notebooks/Thesis/trained_models/autoencoder_multiple_simulations_model.h5')
#     autoencoder_energy_2.save('C:/Users/hmpor/Jupyter Notebooks/Thesis/trained_models/autoencoder_multiple_simulations_model.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
names_models = ["dense_1_8_01_linear_linear", "dense_2_8_01_linear_linear", "dense_3_8_01_linear_linear", "dense_1_custom_loss_8_01_linear_linear", "dense_2_custom_loss_8_01_linear_linear", "dense_3_custom_loss_8_01_linear_linear"]

# %%
import pickle

# names_models = ["dense_1_8_01_leakyrelu_tanh", "dense_2_8_01_leakyrelu_tanh", "dense_3_8_01_leakyrelu_tanh", "dense_1_custom_loss_8_01_leakyrelu_tanh", "dense_2_custom_loss_8_01_leakyrelu_tanh", "dense_3_custom_loss_8_01_leakyrelu_tanh"]

histories = []

for i, _ in enumerate(names_models):    
    with open(f"C:/Users/hmpor/Jupyter Notebooks/Thesis/Model training/Models/LL_bonus/{names_models[i]}.pkl", 'rb') as pickle_file:
        history = pickle.load(pickle_file)
    
    histories.append(history)

# %%
names = ["dense_1", "dense_2", "dense_3", "dense_1_custom_loss", "dense_2_custom_loss", "dense_3_custom_loss"]
colors = ["blue", "orange", "green", "red", "purple", "brown", "pink", "gray", "lime", "cyan"]

import matplotlib.pyplot as plt

def plot_training_histories(histories, colors, names, ylim, skip=0, title="plot.png"):
    """Plots training and validation loss curves for multiple models.

    Args:
        histories (list): List of Keras History objects.
        colors (list): List of colors for each model's line.
        names (list): List of names for each model.
    """

    plt.figure(figsize=(6, 4))

    for history, color, name in zip(histories, colors, names):
        # Extract training and validation loss from history
        train_loss = history['loss'][skip:]
        val_loss = history['val_loss'][skip:]
        epochs = range(1, len(train_loss) + 1)

        # Plot training loss (solid line)
        plt.plot(epochs, train_loss, color=color, label=f'{name} (train)', linestyle='-')

        # Plot validation loss (dashed line)
        plt.plot(epochs, val_loss, color=color, label=f'{name} (test)', linestyle='--')

    # Add labels, title, and legend
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.xlim(0, 100)
    if ylim != (0, 0):
        plt.ylim(ylim)
    plt.legend()

    # Show the plot
    plt.grid(True)
    plt.savefig(title, bbox_inches='tight')
    plt.show()

plot_training_histories(histories[:3], colors, names[:3], (0.0, 0.04), skip=0, title="mse_LL.png")
plot_training_histories(histories[3:], colors, names[3:], (0.3, 1.8), skip=0, title="ED_LL.png")

from tensorflow.keras.models import load_model

models = []
# names_models = ["dense_1_8_01_leakyrelu_tanh", "dense_2_8_01_leakyrelu_tanh", "dense_3_8_01_leakyrelu_tanh", "dense_1_custom_loss_8_01_leakyrelu_tanh", "dense_2_custom_loss_8_01_leakyrelu_tanh", "dense_3_custom_loss_8_01_leakyrelu_tanh"]
base_path = "C:/Users/hmpor/Jupyter Notebooks/Thesis/Model training/Models/LL_bonus/"
paths = []

for model_name in names_models:
    model_path = base_path + model_name + ".h5"  # Load the .h5 format
    paths.append(model_path)
    
def calculate_angles(sin_cos_conf, L):
    angles_conf = tf.atan2(sin_cos_conf[:, :L*L], sin_cos_conf[:, L*L:], )
    return angles_conf

def periodic_index(value, max_value):
    return tf.math.mod(value, max_value)


def periodic_diff(angle1, angle2):
    diff = angle1 - angle2
    diff = tf.where(diff > np.pi, diff - 2 * np.pi, diff)
    diff = tf.where(diff < -np.pi, diff + 2 * np.pi, diff)
    return diff

@tf.function
def calculate_single_lattice_energy(angles, L, J):
    # shape of the input data: number of elements in the batch, L, L
    angles = tf.reshape(angles, (L, L))

    indices = tf.range(L)
    grid_x, grid_y = tf.meshgrid(indices, indices)
    
    cell_indices = tf.stack([grid_x, grid_y], axis=-1)
    cell_indices = tf.reshape(cell_indices, (-1, 2))


    def energy_per_cell(index):
        # indices in this iteration
        i = index[0]
        j = index[1]

        neighbors = [
            angles[periodic_index(i + 1, L), j], # down
            angles[periodic_index(i - 1, L), j], # up
            angles[i, periodic_index(j + 1, L)], # right
            angles[i, periodic_index(j - 1, L)]  # left
        ]

        local_energy = tf.reduce_sum(-J * tf.math.cos(periodic_diff(angles[i, j], neighbors)))
        return local_energy


    energy_contributions = tf.vectorized_map(
            energy_per_cell,
            cell_indices
    )
    total_energy = tf.reduce_sum(energy_contributions) 

    return total_energy / 2

@tf.function
def calculate_energy(angles_batch, L, J):
    energies = tf.vectorized_map(
        lambda angles: calculate_single_lattice_energy(angles, L, J),
        angles_batch
    )
    return energies

@tf.function
def energy_difference(y_true, y_pred):
#     tf.config.run_functions_eagerly(False)
    L = 8
    J = 1
 
    y_true_angles = calculate_angles(y_true, L)
    y_pred_angles = calculate_angles(y_pred, L)
    
    true_energies = calculate_energy(y_true_angles, L, J)
    pred_energies = calculate_energy(y_pred_angles, L, J)
    
    true_energies = tf.cast(true_energies, tf.float64)
    pred_energies = tf.cast(pred_energies, tf.float64)
    
    energy_diff = tf.abs(true_energies - pred_energies)
    mean_energy_diff = tf.reduce_mean(energy_diff)
    
    return mean_energy_diff

dense_1 = autoencoder_dense_1(input_shape)
dense_1.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
dense_1.load_weights(paths[0])

dense_2 = autoencoder_dense_2(input_shape)
dense_2.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
dense_2.load_weights(paths[1])

dense_3 = autoencoder_dense_3(input_shape)
dense_3.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
dense_3.load_weights(paths[2])

dense_1_ed = autoencoder_dense_1(input_shape)
dense_1_ed.compile(optimizer='adam', loss=energy_difference, metrics=['accuracy'])
dense_1_ed.load_weights(paths[3])

dense_2_ed = autoencoder_dense_2(input_shape)
dense_2_ed.compile(optimizer='adam', loss=energy_difference, metrics=['accuracy'])
dense_2_ed.load_weights(paths[4])

dense_3_ed = autoencoder_dense_3(input_shape)
dense_3_ed.compile(optimizer='adam', loss=energy_difference, metrics=['accuracy'])
dense_3_ed.load_weights(paths[5])    


from sklearn.metrics import mean_squared_error

models = [dense_1, dense_2, dense_3, dense_1_ed, dense_2_ed, dense_3_ed]
score_mse = []
score_ed = []

for i, model in enumerate(models):
    predictions = model.predict(inputs_val)
    
    outputs_val_casted = tf.cast(outputs_val, tf.float64)
    predictions_casted = tf.cast(predictions, tf.float64)
    
    mse_value = mean_squared_error(outputs_val, predictions)
    ed_value = energy_difference(outputs_val, predictions)
    
    score_mse.append(mse_value)
    score_ed.append(ed_value)
   
print(score_mse)
print(score_ed)
# Out:
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# [0.007798589803600508, 0.012030987702792574, 0.016648279060799527, 6.987787385952975, 9.208469485003281, 57.34516764541468]
# [<tf.Tensor: shape=(), dtype=float64, numpy=2.0705377573452797>, <tf.Tensor: shape=(), dtype=float64, numpy=2.8102022042726396>, <tf.Tensor: shape=(), dtype=float64, numpy=3.257208720981393>, <tf.Tensor: shape=(), dtype=float64, numpy=0.4518867337405854>, <tf.Tensor: shape=(), dtype=float64, numpy=0.5106783858728496>, <tf.Tensor: shape=(), dtype=float64, numpy=0.5846293758167773>]
